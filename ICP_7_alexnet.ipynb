# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.optimizers import RMSprop, Adam
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import classification_report, confusion_matrix
import warnings
warnings.filterwarnings("ignore")

# %%
(x_train, y_train), (x_test, y_test)  = keras.datasets.cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 4s 0us/step

# %%
classes = ["airplane","automobile","bird","cat","deer","dog","frog","horse","ship","truck"]

# %%
y_train = y_train.reshape(-1,)

# %%
# Reshape converting 2D to 1D
y_test = y_test.reshape(-1,)
y_train = y_train.reshape(-1,)

# %%
# This code normalazation
x_train = x_train / 255.0
x_test = x_test / 255.0

# %%
x_train.shape
# Out:
# (50000, 32, 32, 3)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, BatchNormalization, MaxPooling2D, Flatten, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Data Augmentation
datagen = ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    zoom_range=0.2
)

# Define Alexnet Model
AlexNet = Sequential()

AlexNet.add(Conv2D(filters=32, kernel_size=(3,3), strides=(1,1), padding='same', input_shape=(32,32,3), activation='relu'))
AlexNet.add(BatchNormalization())
AlexNet.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))

AlexNet.add(Conv2D(filters=64, kernel_size=(5,5), strides=(1,1), padding='same', activation='relu'))
AlexNet.add(BatchNormalization())
AlexNet.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))

AlexNet.add(Conv2D(filters=128, kernel_size=(3,3), strides=(1,1), padding='same', activation='relu'))
AlexNet.add(BatchNormalization())

AlexNet.add(Conv2D(filters=128, kernel_size=(3,3), strides=(1,1), padding='same', activation='relu'))
AlexNet.add(BatchNormalization())

AlexNet.add(Conv2D(filters=64, kernel_size=(3,3), strides=(1,1), padding='same', activation='relu'))
AlexNet.add(BatchNormalization())
AlexNet.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))

AlexNet.add(Flatten())
AlexNet.add(Dense(512, activation='relu'))
AlexNet.add(Dropout(0.5))

AlexNet.add(Dense(256, activation='relu'))
AlexNet.add(Dropout(0.5))

AlexNet.add(Dense(10, activation='softmax'))

# Define optimizer
opt = Adam(learning_rate=0.001)

# Compile model with 'sparse_categorical_crossentropy'
AlexNet.compile(optimizer=opt, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Print model summary
AlexNet.summary()

# Train model
history = AlexNet.fit(datagen.flow(x_train, y_train, batch_size=64),
                      epochs=50,
                      validation_data=(x_test, y_test),
                      verbose=1)

# Access validation loss and accuracy
val_loss = history.history['val_loss']
val_acc = history.history['val_accuracy']
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  batch_normalization (BatchN  (None, 32, 32, 32)       128
#  ormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 16, 16, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 16, 16, 64)        51264
#
#  batch_normalization_1 (Batc  (None, 16, 16, 64)       256
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 8, 8, 64)         0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 8, 8, 128)         73856
#
#  batch_normalization_2 (Batc  (None, 8, 8, 128)        512
#  hNormalization)
#
#  conv2d_3 (Conv2D)           (None, 8, 8, 128)         147584
#
#  batch_normalization_3 (Batc  (None, 8, 8, 128)        512
#  hNormalization)
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 64)          73792
#
#  batch_normalization_4 (Batc  (None, 8, 8, 64)         256
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 4, 4, 64)         0
#  2D)
#
#  flatten (Flatten)           (None, 1024)              0
#
#  dense (Dense)               (None, 512)               524800
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 10)                2570
#
# =================================================================
# Total params: 1,007,754
# Trainable params: 1,006,922
# Non-trainable params: 832
# _________________________________________________________________
# Epoch 1/50
# 782/782 [==============================] - 49s 44ms/step - loss: 1.8065 - accuracy: 0.3554 - val_loss: 2.1731 - val_accuracy: 0.2812
# Epoch 2/50
# 782/782 [==============================] - 32s 41ms/step - loss: 1.4211 - accuracy: 0.4966 - val_loss: 1.4267 - val_accuracy: 0.5103
# Epoch 3/50
# 782/782 [==============================] - 33s 42ms/step - loss: 1.2473 - accuracy: 0.5664 - val_loss: 1.4533 - val_accuracy: 0.5081
# Epoch 4/50
# 782/782 [==============================] - 33s 42ms/step - loss: 1.1324 - accuracy: 0.6103 - val_loss: 1.1016 - val_accuracy: 0.6163
# Epoch 5/50
# 782/782 [==============================] - 32s 41ms/step - loss: 1.0502 - accuracy: 0.6432 - val_loss: 0.9924 - val_accuracy: 0.6532
# Epoch 6/50
# 782/782 [==============================] - 33s 42ms/step - loss: 0.9813 - accuracy: 0.6669 - val_loss: 1.2696 - val_accuracy: 0.5798
# Epoch 7/50
# 782/782 [==============================] - 31s 39ms/step - loss: 0.9346 - accuracy: 0.6867 - val_loss: 0.8717 - val_accuracy: 0.7004
# Epoch 8/50
# 782/782 [==============================] - 33s 42ms/step - loss: 0.8849 - accuracy: 0.7052 - val_loss: 0.8104 - val_accuracy: 0.7269
# Epoch 9/50
# 782/782 [==============================] - 31s 40ms/step - loss: 0.8420 - accuracy: 0.7203 - val_loss: 1.1097 - val_accuracy: 0.6373
# Epoch 10/50
# 782/782 [==============================] - 32s 41ms/step - loss: 0.8032 - accuracy: 0.7304 - val_loss: 0.7912 - val_accuracy: 0.7285
# Epoch 11/50
# 782/782 [==============================] - 32s 41ms/step - loss: 0.7674 - accuracy: 0.7434 - val_loss: 0.7547 - val_accuracy: 0.7455
# Epoch 12/50
# 782/782 [==============================] - 32s 42ms/step - loss: 0.7422 - accuracy: 0.7542 - val_loss: 0.5807 - val_accuracy: 0.8053
# Epoch 13/50
# 782/782 [==============================] - 34s 43ms/step - loss: 0.7238 - accuracy: 0.7600 - val_loss: 0.7687 - val_accuracy: 0.7381
# Epoch 14/50
# 782/782 [==============================] - 31s 40ms/step - loss: 0.6971 - accuracy: 0.7683 - val_loss: 0.6103 - val_accuracy: 0.7910
# Epoch 15/50
# 782/782 [==============================] - 32s 41ms/step - loss: 0.6718 - accuracy: 0.7763 - val_loss: 0.6803 - val_accuracy: 0.7724
# Epoch 16/50
# 782/782 [==============================] - 32s 41ms/step - loss: 0.6520 - accuracy: 0.7835 - val_loss: 0.8940 - val_accuracy: 0.7228
# Epoch 17/50
# 782/782 [==============================] - 31s 40ms/step - loss: 0.6367 - accuracy: 0.7878 - val_loss: 0.6098 - val_accuracy: 0.7961
# Epoch 18/50
# 782/782 [==============================] - 32s 41ms/step - loss: 0.6175 - accuracy: 0.7953 - val_loss: 0.6884 - val_accuracy: 0.7770
# Epoch 19/50
# 782/782 [==============================] - 33s 42ms/step - loss: 0.6015 - accuracy: 0.7992 - val_loss: 0.6444 - val_accuracy: 0.7813
# Epoch 20/50
# 782/782 [==============================] - 33s 42ms/step - loss: 0.5899 - accuracy: 0.8041 - val_loss: 0.7776 - val_accuracy: 0.7494
# Epoch 21/50
# 782/782 [==============================] - 32s 41ms/step - loss: 0.5704 - accuracy: 0.8112 - val_loss: 0.5586 - val_accuracy: 0.8107
# Epoch 22/50
# 782/782 [==============================] - 33s 42ms/step - loss: 0.5618 - accuracy: 0.8139 - val_loss: 0.5397 - val_accuracy: 0.8176
# Epoch 23/50
# 782/782 [==============================] - 32s 40ms/step - loss: 0.5516 - accuracy: 0.8151 - val_loss: 0.8017 - val_accuracy: 0.7389
# Epoch 24/50
# 782/782 [==============================] - 34s 43ms/step - loss: 0.5377 - accuracy: 0.8197 - val_loss: 0.6854 - val_accuracy: 0.7721
# Epoch 25/50
# 782/782 [==============================] - 31s 40ms/step - loss: 0.5317 - accuracy: 0.8232 - val_loss: 0.5761 - val_accuracy: 0.8106
# Epoch 26/50
# 782/782 [==============================] - 32s 41ms/step - loss: 0.5119 - accuracy: 0.8291 - val_loss: 0.4979 - val_accuracy: 0.8324
# Epoch 27/50
# 782/782 [==============================] - 32s 41ms/step - loss: 0.5072 - accuracy: 0.8286 - val_loss: 0.5130 - val_accuracy: 0.8275
# Epoch 28/50
# 782/782 [==============================] - 32s 41ms/step - loss: 0.5016 - accuracy: 0.8333 - val_loss: 0.5705 - val_accuracy: 0.8131
# Epoch 29/50
# 782/782 [==============================] - 32s 40ms/step - loss: 0.4899 - accuracy: 0.8370 - val_loss: 0.5446 - val_accuracy: 0.8222
# Epoch 30/50
# 782/782 [==============================] - 33s 42ms/step - loss: 0.4900 - accuracy: 0.8368 - val_loss: 0.5989 - val_accuracy: 0.8049
# Epoch 31/50
# 782/782 [==============================] - 31s 40ms/step - loss: 0.4805 - accuracy: 0.8392 - val_loss: 0.4881 - val_accuracy: 0.8340
# Epoch 32/50
# 782/782 [==============================] - 32s 41ms/step - loss: 0.4786 - accuracy: 0.8401 - val_loss: 0.4657 - val_accuracy: 0.8456
# Epoch 33/50
# 782/782 [==============================] - 32s 41ms/step - loss: 0.4659 - accuracy: 0.8446 - val_loss: 0.4366 - val_accuracy: 0.8524
# Epoch 34/50
# 782/782 [==============================] - 32s 41ms/step - loss: 0.4636 - accuracy: 0.8453 - val_loss: 0.4557 - val_accuracy: 0.8478
# Epoch 35/50
# 782/782 [==============================] - 32s 41ms/step - loss: 0.4551 - accuracy: 0.8463 - val_loss: 0.5830 - val_accuracy: 0.8071
# Epoch 36/50
# 782/782 [==============================] - 32s 42ms/step - loss: 0.4488 - accuracy: 0.8517 - val_loss: 0.6221 - val_accuracy: 0.8001
# Epoch 37/50
# 782/782 [==============================] - 32s 41ms/step - loss: 0.4448 - accuracy: 0.8517 - val_loss: 0.4659 - val_accuracy: 0.8476
# Epoch 38/50
# 782/782 [==============================] - 31s 40ms/step - loss: 0.4377 - accuracy: 0.8530 - val_loss: 0.5411 - val_accuracy: 0.8228
# Epoch 39/50
# 782/782 [==============================] - 32s 41ms/step - loss: 0.4378 - accuracy: 0.8540 - val_loss: 0.5741 - val_accuracy: 0.8186
# Epoch 40/50
# 782/782 [==============================] - 32s 40ms/step - loss: 0.4308 - accuracy: 0.8575 - val_loss: 0.5074 - val_accuracy: 0.8317
# Epoch 41/50
# 782/782 [==============================] - 31s 40ms/step - loss: 0.4275 - accuracy: 0.8554 - val_loss: 0.5382 - val_accuracy: 0.8265
# Epoch 42/50
# 782/782 [==============================] - 33s 42ms/step - loss: 0.4182 - accuracy: 0.8589 - val_loss: 0.4679 - val_accuracy: 0.8436
# Epoch 43/50
# 782/782 [==============================] - 31s 40ms/step - loss: 0.4160 - accuracy: 0.8611 - val_loss: 0.5901 - val_accuracy: 0.8137
# Epoch 44/50
# 782/782 [==============================] - 31s 40ms/step - loss: 0.4173 - accuracy: 0.8600 - val_loss: 0.4623 - val_accuracy: 0.8471
# Epoch 45/50
# 782/782 [==============================] - 31s 39ms/step - loss: 0.4031 - accuracy: 0.8648 - val_loss: 0.4763 - val_accuracy: 0.8461
# Epoch 46/50
# 782/782 [==============================] - 31s 40ms/step - loss: 0.4076 - accuracy: 0.8627 - val_loss: 0.4748 - val_accuracy: 0.8443
# Epoch 47/50
# 782/782 [==============================] - 31s 40ms/step - loss: 0.3995 - accuracy: 0.8656 - val_loss: 0.5244 - val_accuracy: 0.8284
# Epoch 48/50
# 782/782 [==============================] - 33s 42ms/step - loss: 0.3994 - accuracy: 0.8654 - val_loss: 0.4463 - val_accuracy: 0.8551
# Epoch 49/50
# 782/782 [==============================] - 31s 40ms/step - loss: 0.3956 - accuracy: 0.8666 - val_loss: 0.4581 - val_accuracy: 0.8460
# Epoch 50/50
# 782/782 [==============================] - 31s 39ms/step - loss: 0.3908 - accuracy: 0.8687 - val_loss: 0.5483 - val_accuracy: 0.8253

# %%
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title("Accuracy by AlexNet on CIFAR-10 Data")
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss by AlexNet on CIFAR-10 Data')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['Train', 'Validation'])
plt.show()

# %%
y_predictions1 = AlexNet.predict(x_test)
y_predictions1.reshape(-1,)
y_predictions1= np.argmax(y_predictions1, axis=1)

confusion_matrix(y_test, y_predictions1)
# Out:
# 313/313 [==============================] - 1s 3ms/step
# array([[843,  13,  39,   5,   7,   1,  10,   1,  47,  34],
#        [  1, 928,   1,   0,   0,   0,   3,   0,   8,  59],
#        [ 26,   0, 829,   7,  37,   9,  71,  10,   6,   5],
#        [  9,   7,  86, 519,  52,  66, 190,  17,  28,  26],
#        [  5,   1,  48,  12, 814,   6,  86,  22,   2,   4],
#        [  8,   8,  69,  75,  50, 618, 114,  34,   7,  17],
#        [  4,   1,  20,   3,   2,   2, 961,   1,   5,   1],
#        [ 10,   1,  23,   9,  42,   8,  20, 872,   3,  12],
#        [ 22,  10,   9,   2,   3,   0,   5,   0, 923,  26],
#        [  6,  22,   5,   2,   2,   0,   3,   2,  12, 946]])

# %%
# confusion matrix and accuracy
plt.figure(figsize=(7, 6))
plt.title('Confusion matrix of AlexNet Model', fontsize=16)
plt.imshow(confusion_matrix(y_test, y_predictions1))
plt.xticks(np.arange(10), classes, rotation=45, fontsize=12)
plt.yticks(np.arange(10), classes, fontsize=12)
plt.colorbar()
plt.show()

# %%
from sklearn.metrics import accuracy_score
print("Test accuracy by AlexNet:", accuracy_score(y_test, y_predictions1))
# Out:
# Test accuracy by AlexNet: 0.8253

# %%
L = 8
W = 8
fig, axes = plt.subplots(L, W, figsize = (20,20))
axes = axes.ravel() # 

for i in np.arange(0, L * W):  
    axes[i].imshow(x_test[i])
    axes[i].set_title("Predicted = {}\n Actual  = {}".format(classes[y_predictions1[i]], classes[y_test[i]]))
    axes[i].axis('off')

plt.subplots_adjust(wspace=1)
